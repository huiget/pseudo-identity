# %% [markdown]
# # Table qs_i_usoc_user_info 用户信息表

# %%
import pandas as pd

# %%
col_names = ["用户编码", "客户编码", "主计费号", "账户编码", "次计费号", "地市编码", "区县编码", "用户状态", "用户类型", "地址编码", "产品规格编码", "催停标志", "用户信用度分档", "用户当前信用度", "品牌编号", "套餐编号", "套餐付费方式", "套餐生效日期", "套餐失效日期", "星级级别", "星级获得原因", "用户在网时长", "用户离网时长", "创建日期", "受理编号", "受理日期", "生效日期", "失效日期", "预销户日期", "渠道编码", "当前业务操作员", "创建操作员", "创建操作员组织", "最近一次过户时间", "停开机操作日期", "停开状态", "帐务停机日期", "商业停机日期", "呼出限制停日期", "连带停机日期", "管理停机日期"]
df_user_info = pd.read_csv('table\qs_i_usoc_user_info_m1', sep='|', header=None, na_values='\\N', names=col_names)

# %%
df_user_info.head()
# Out:
#            用户编码  客户编码        主计费号        账户编码             次计费号  地市编码  区县编码  \
# 7138446189  NaN     0  7125920698  7129541290  460023886901713   571  571A
# 7734353333  NaN     0  7723267842  7727773598  460008783664619   577  5772
# 7922832641  NaN     0  7917231872  7918575746  460075558711935   579  5791
# 7105720032  NaN     0  7104669988  5024895543  460026680333614   571  5711
# 7924934499  NaN     0  7918316389  7919603150  460008993536687   579  5799
#
#             用户状态  用户类型  地址编码         ...              创建操作员   创建操作员组织  \
# 7138446189     1     1   0.0         ...           20030357  40042315
# 7734353333     1     1   0.0         ...           20060442  40115930
# 7922832641     1     1   0.0         ...           20055198  40101811
# 7105720032     1     1   0.0         ...           20007130  10000035
# 7924934499     1     1   0.0         ...           20099615  40108065
#
#             最近一次过户时间              停开机操作日期                停开状态  \
# ...

# %%
use_cols = []

# %% [markdown]
# # Table qs_i_uprd_call 话单

# %%
col_names = ['用户编号','CL_TIME','FLAG','客户标识','帐户编号','地市代码','县市代码','品牌编码','套餐计划','漫游省份','漫游地市','服务标识','话单类型','计费标识','通话类型','长途类型','漫游类型','特殊接入类型','运营商关系类型','对端号码类型','呼叫时段分档','网络类型','亲情网标识','亲情网短号标识','可视电话标志','漫游网络类型','通话次数','计费通话次数','通话时长_秒','通话时长_分钟','收费通话时长_分钟','基本通话费','基本通话费优惠','长途费','长途费优惠','费用3','费用3优惠','其它费','其它费优惠','免费资源量','漫游天数','省内漫游天数','省际漫游天数','国际漫游天数','月免费通话总时长（秒）','月免费通话总时长（分）','月免费通话时长使用量（秒）','月免费通话时长使用量（分）']
df_call = pd.read_csv('table\qs_i_uprd_call_m1' ,sep='|', header=None, na_values='\\N', names=col_names, nrows=100)

# %%
df_call[0:3].transpose()
# Out:
#                         0           1           2
# 用户编号           2091899993  2007099072  2033654318
# CL_TIME               NaN         NaN         NaN
# FLAG                    0           0           0
# 客户标识                   -1          -1          -1
# 帐户编号           2099812652  2006716601  2032671444
# 地市代码                  574         578         575
# 县市代码                 574C        5783        5753
# 品牌编码                    1           1           1
# 套餐计划             70009103    70009103    70009899
# 漫游省份                  571         571         571
# 漫游地市                  574         578         575
# 服务标识                50001       50001       50001
# 话单类型                    0           0           0
# 计费标识                    0           0           0
# 通话类型                    0           0           1
# 长途类型                    0           0           0
# 漫游类型                    0           0           0
# 特殊接入类型                  0           0           0
# ...
